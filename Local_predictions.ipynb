# %%
import sys 
sys.path.append("./fonction_ressources")

# %%
import os
import pickle 
import numpy as np
import cv2 
import matplotlib.pyplot as plt 
from  make_copy import  make_copy_dir
from preprocessing import preprocessing

# %%
pictures_location=make_copy_dir("C:/Users/Utilisateur/Desktop/projets/briefs/b13_mnist/mnist/pictures")
drawing_location=make_copy_dir("C:/Users/Utilisateur/Desktop/projets/briefs/b13_mnist/mnist/drawing")
pictures_location,drawing_location
# Out:
# ('C:/Users/Utilisateur/Desktop/projets/briefs/b13_mnist/mnist/pictures_copy',
#  'C:/Users/Utilisateur/Desktop/projets/briefs/b13_mnist/mnist/drawing_copy')

# %%
# load image
photo = [filename for filename in os.listdir(pictures_location) ]
photo
# Out:
# ['pic0.png',
#  'pic4.png',
#  'pic8.png',
#  'picture2.png',
#  'picture4.png',
#  'picture7.png',
#  'picture9webp.png',
#  'pictures_5.png',
#  'pictures_6.png',
#  'picture_1.png',
#  'picture_3.png',
#  'picture_6.png',
#  'picture_8.png',
#  'webcam_4.png']

# %%
# load drawing
dessin = [filename for filename in os.listdir(drawing_location) ]
dessin
# Out:
# ['drawing(1).png', 'drawing(7).png', 'drawing(8).png', 'drawing(9).png']

# %%
from PIL import Image

for x in dessin:
    img = Image.open(drawing_location+"/"+x)
    # new_name=x[:x.index(".")]
    img.save(drawing_location+"/"+x, 'png')

# %%
for x in photo:
    img = Image.open(pictures_location+"/"+x)
    img.save(pictures_location+"/"+x, 'png')

# %%
plt.imshow(img)

# %%
# processing photo et dessin 
preprocessing(photo,(28,28))
preprocessing(dessin,(28,28))

# %%
for x in dessin : 
    cv2.imread(x)
    plt.imshow(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 for x in dessin :
#       2     cv2.imread(x)
# ----> 3     plt.imshow(x)
#
# File c:\Users\Utilisateur\anaconda3\Lib\site-packages\matplotlib\pyplot.py:2695, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2689 @_copy_docstring_and_deprecators(Axes.imshow)
#    2690 def imshow(
#    2691         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2692         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2693         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2694         resample=None, url=None, data=None, **kwargs):
# -> 2695     __ret = gca().imshow(
#    2696         X, cmap=cmap, norm=norm, aspect=aspect,
# ...

# %%
photo_loaded = [cv2.imread(x) for x in photo]

# %%
photo_loaded
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# load model

digit=open("trained_model/mnist_digit",'rb')
digit = pickle.load(digit)

# letter=open("trained_model/mnist_letter",'rb')
# letter = pickle.load(letter)

# fashion = open("trained_model/mnist_fashion",'rb')
# fashion = pickle.load(fashion)

# balanced = open("trained_model/mnist_balanced",'rb')
# balanced = pickle.load(balanced)
# Out:
# WARNING:tensorflow:From c:\Users\Utilisateur\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\Utilisateur\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Utilisateur\anaconda3\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
prediction=digit.predict(photo_loaded)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 prediction=digit.predict(photo_loaded)
#
# File c:\Users\Utilisateur\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Utilisateur\anaconda3\Lib\site-packages\keras\src\engine\data_adapter.py:1105, in select_data_adapter(x, y)
#    1102 adapter_cls = [cls for cls in ALL_ADAPTER_CLS if cls.can_handle(x, y)]
#    1103 if not adapter_cls:
#    1104     # TODO(scottzhu): This should be a less implementation-specific error.
# ...

# %%
print(np.argmax(prediction))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 print(np.argmax(prediction))
#
# NameError: name 'prediction' is not defined

# %%
# predict 
for x in photo+dessin: 
    
    digit.predict(np.array(x))
    pass
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 4
#       1 # predict
#       2 for x in photo+dessin:
# ----> 4     digit.predict(np.array(x))
#       5     pass
#
# File c:\Users\Utilisateur\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File c:\Users\Utilisateur\anaconda3\Lib\site-packages\tensorflow\python\framework\tensor_shape.py:962, in TensorShape.__getitem__(self, key)
#     960 else:
#     961   if self._v2_behavior:
# --> 962     return self._dims[key]
#     963   else:
# ...
